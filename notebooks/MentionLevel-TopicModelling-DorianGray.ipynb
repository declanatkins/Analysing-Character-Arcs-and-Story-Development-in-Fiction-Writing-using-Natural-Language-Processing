# %%
import pandas as pd

# %%
entities_df = pd.read_csv('../data/DorianGray/processed_characters.csv')
tokens_df = pd.read_csv('../data/DorianGray/character-tagging/DorianGray.tokens', delimiter='\t')
entities_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat               text  \
# 0              4    112           77         79  PROP  PER  Lord Henry Wotton
# 1              6    112          156        156  PRON  PER                him
# 2             14    113          289        290  PROP  PER     Basil Hallward
# 3             27    113          396        396  PROP  PER              Basil
# 4             29    112          408        409  PROP  PER         Lord Henry
# ...          ...    ...          ...        ...   ...  ...                ...
# 7166       14196    307        95668      95668  PRON  PER                 he
# 7167       14197    307        95674      95674  PRON  PER                 He
# 7168       14215    115        95814      95816  PROP  PER    Mr. Dorian Gray
# 7169       14232    268        95885      95885  PROP  PER            Francis
# 7170       14233    268        95900      95900  PRON  PER                 he
#
#       orig_coref     character_name
# 0          112.0  Lord Henry Wotton
# 1          112.0  Lord Henry Wotton
# 2          112.0     Basil Hallward
# 3          113.0     Basil Hallward
# 4          113.0  Lord Henry Wotton
# ...          ...                ...
# 7166         NaN      Alan Campbell
# 7167         NaN      Alan Campbell
# 7168         NaN    Mr. Dorian Gray
# 7169         NaN    Francis Osborne
# 7170         NaN    Francis Osborne
#
# [7171 rows x 9 columns]

# %%
tokens_df
# Out:
#        paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0                 0            0                         0
# 1                 0            0                         1
# 2                 0            0                         2
# 3                 0            0                         3
# 4                 0            0                         4
# ...             ...          ...                       ...
# 96039          1490         6159                        11
# 96040          1490         6159                        12
# 96041          1490         6159                        13
# 96042          1490         6159                        14
# 96043          1490         6159                        15
#
#        token_ID_within_document        word      lemma  byte_onset  \
# 0                             0         The        the           0
# 1                             1      studio     studio           4
# 2                             2         was         be          11
# 3                             3      filled       fill          15
# 4                             4        with       with          22
# ...                         ...         ...        ...         ...
# 96039                     96039  recognized  recognize      426538
# 96040                     96040         who        who      426549
# 96041                     96041          it         it      426553
# 96042                     96042         was         be      426556
# 96043                     96043           .          .      426559
#
#       byte_offset POS_tag fine_POS_tag dependency_relation syntactic_head_ID  \
# 0               3     DET           DT                 det                 1
# 1              10    NOUN           NN           nsubjpass                 3
# 2              14     AUX          VBD             auxpass                 3
# 3              21    VERB          VBN                ROOT                 3
# 4              26     ADP           IN                prep                 3
# ...           ...     ...          ...                 ...               ...
# 96039      426548    VERB          VBD               relcl             96036
# 96040      426552    PRON           WP                attr             96042
# 96041      426555    PRON          PRP               nsubj             96042
# 96042      426559     AUX          VBD               ccomp             96039
# 96043      426560   PUNCT            .               punct             96029
#
#       event
# 0         O
# 1         O
# 2         O
# 3         O
# 4         O
# ...     ...
# 96039     O
# 96040     O
# 96041     O
# 96042     O
# 96043     O
#
# [96044 rows x 13 columns]

# %%
character_of_interest = 'Mr. Dorian Gray'
token_window = 100

# %%
mentions_df = entities_df[entities_df.character_name == character_of_interest]
mentions_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat             text  \
# 44           155    115         1235       1236  PROP  PER      Dorian Gray
# 45           159    115         1258       1259  PROP  PER      Dorian Gray
# 46           160    115         1263       1263  PRON  PER              his
# 49           164    115         1284       1284  PRON  PER              his
# 116          266    115         1852       1853  PROP  PER      Dorian Gray
# ...          ...    ...          ...        ...   ...  ...              ...
# 7076       14083    115        94674      94674  PRON  PER               He
# 7077       14084    115        94678      94678  PRON  PER              him
# 7079       14086    115        94695      94695  PRON  PER              him
# 7080       14087    115        94702      94702  PRON  PER               he
# 7168       14215    115        95814      95816  PROP  PER  Mr. Dorian Gray
#
#       orig_coref   character_name
# 44         115.0  Mr. Dorian Gray
# 45         112.0  Mr. Dorian Gray
# 46         116.0  Mr. Dorian Gray
# 49         112.0  Mr. Dorian Gray
# 116        115.0  Mr. Dorian Gray
# ...          ...              ...
# 7076         NaN  Mr. Dorian Gray
# 7077         NaN  Mr. Dorian Gray
# 7079         NaN  Mr. Dorian Gray
# 7080         NaN  Mr. Dorian Gray
# 7168         NaN  Mr. Dorian Gray
#
# [3063 rows x 9 columns]
