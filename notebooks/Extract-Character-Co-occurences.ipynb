# %%
import pandas as pd
import networkx as nx
import igviz as ig

# %%
characters_df = pd.read_csv('../data/DorianGray/processed_characters.csv')
characters_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat               text  \
# 0              4    112           77         79  PROP  PER  Lord Henry Wotton
# 1              6    112          156        156  PRON  PER                him
# 2             14    113          289        290  PROP  PER     Basil Hallward
# 3             27    113          396        396  PROP  PER              Basil
# 4             29    112          408        409  PROP  PER         Lord Henry
# ...          ...    ...          ...        ...   ...  ...                ...
# 7148       14196    307        95668      95668  PRON  PER                 he
# 7149       14197    307        95674      95674  PRON  PER                 He
# 7150       14215    115        95814      95816  PROP  PER    Mr. Dorian Gray
# 7151       14232    268        95885      95885  PROP  PER            Francis
# 7152       14233    268        95900      95900  PRON  PER                 he
#
#          character_name
# 0     Lord Henry Wotton
# 1     Lord Henry Wotton
# 2        Basil Hallward
# 3        Basil Hallward
# 4     Lord Henry Wotton
# ...                 ...
# 7148      Alan Campbell
# 7149      Alan Campbell
# 7150    Mr. Dorian Gray
# 7151    Francis Osborne
# 7152    Francis Osborne
#
# [7153 rows x 8 columns]

# %%
tokens_df = pd.read_csv('../data/DorianGray/character-tagging/DorianGray.tokens', delimiter='\t')
tokens_df
# Out:
#        paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0                 0            0                         0
# 1                 0            0                         1
# 2                 0            0                         2
# 3                 0            0                         3
# 4                 0            0                         4
# ...             ...          ...                       ...
# 96039          1490         6159                        11
# 96040          1490         6159                        12
# 96041          1490         6159                        13
# 96042          1490         6159                        14
# 96043          1490         6159                        15
#
#        token_ID_within_document        word      lemma  byte_onset  \
# 0                             0         The        the           0
# 1                             1      studio     studio           4
# 2                             2         was         be          11
# 3                             3      filled       fill          15
# 4                             4        with       with          22
# ...                         ...         ...        ...         ...
# 96039                     96039  recognized  recognize      426538
# 96040                     96040         who        who      426549
# 96041                     96041          it         it      426553
# 96042                     96042         was         be      426556
# 96043                     96043           .          .      426559
#
#       byte_offset POS_tag fine_POS_tag dependency_relation syntactic_head_ID  \
# 0               3     DET           DT                 det                 1
# 1              10    NOUN           NN           nsubjpass                 3
# 2              14     AUX          VBD             auxpass                 3
# 3              21    VERB          VBN                ROOT                 3
# 4              26     ADP           IN                prep                 3
# ...           ...     ...          ...                 ...               ...
# 96039      426548    VERB          VBD               relcl             96036
# 96040      426552    PRON           WP                attr             96042
# 96041      426555    PRON          PRP               nsubj             96042
# 96042      426559     AUX          VBD               ccomp             96039
# 96043      426560   PUNCT            .               punct             96029
#
#       event
# 0         O
# 1         O
# 2         O
# 3         O
# 4         O
# ...     ...
# 96039     O
# 96040     O
# 96041     O
# 96042     O
# 96043     O
#
# [96044 rows x 13 columns]

# %%
# Paragraph based network

characters_paragraph_mention_df = characters_df.copy()
characters_paragraph_mention_df['paragraph'] = characters_paragraph_mention_df.start_token.map(
    lambda x: tokens_df.iloc[x].paragraph_ID
)
characters_paragraph_mention_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat               text  \
# 0              4    112           77         79  PROP  PER  Lord Henry Wotton
# 1              6    112          156        156  PRON  PER                him
# 2             14    113          289        290  PROP  PER     Basil Hallward
# 3             27    113          396        396  PROP  PER              Basil
# 4             29    112          408        409  PROP  PER         Lord Henry
# ...          ...    ...          ...        ...   ...  ...                ...
# 7148       14196    307        95668      95668  PRON  PER                 he
# 7149       14197    307        95674      95674  PRON  PER                 He
# 7150       14215    115        95814      95816  PROP  PER    Mr. Dorian Gray
# 7151       14232    268        95885      95885  PROP  PER            Francis
# 7152       14233    268        95900      95900  PRON  PER                 he
#
#          character_name  paragraph
# 0     Lord Henry Wotton          1
# 1     Lord Henry Wotton          1
# 2        Basil Hallward          2
# 3        Basil Hallward          4
# 4     Lord Henry Wotton          4
# ...                 ...        ...
# 7148      Alan Campbell       1483
# 7149      Alan Campbell       1483
# 7150    Mr. Dorian Gray       1486
# 7151    Francis Osborne       1488
# 7152    Francis Osborne       1489
#
# [7153 rows x 9 columns]

# %%
paragraph_windows = 10
paragraphs_per_window = characters_paragraph_mention_df.paragraph.max() // paragraph_windows

sizes = paragraph_windows * [paragraphs_per_window]
for i in range(characters_paragraph_mention_df.paragraph.max() - sum(sizes)):
    sizes[i] += 1

# %%
graphs = []

G = nx.Graph()

curr_graph = 0

for paragraph, sub_df in characters_paragraph_mention_df.groupby(characters_paragraph_mention_df.paragraph):
    
    if paragraph > sizes[curr_graph] + sum(sizes[:curr_graph]):
        graphs.append(G)
        curr_graph += 1
        G = nx.Graph()
    
    if sub_df.character_name.unique().size == 1:
        continue
    
    pairs = []
    for i, name in enumerate(sub_df.character_name.unique()):
        
        if name not in G.nodes:
            G.add_node(name, connections=sub_df.character_name.unique().size - 1)
        else:
            G.nodes[name]['connections'] += sub_df.character_name.unique().size - 1

        for o_name in sub_df.character_name.unique()[i + 1:]:
            
            if o_name not in G.nodes:
                G.add_node(o_name, connections=0)
            if (name, o_name) not in G.edges:
                G.add_edge(name, o_name, weight=1)
            else:
                G.edges[name, o_name]['weight'] += 1

# %%
window = 5

color_list = []
sizing_list = []

G = graphs[window]

for node in G.nodes():
    size_and_color = G.nodes[node]['connections']

    color_list.append(size_and_color)
    sizing_list.append(size_and_color)

ig.plot(
    G,
    title=f"Window {window} Social Network",
    layout="spring",
    size_method=sizing_list, # Makes node sizes the size of the "prop" property
    color_method=color_list, # Colors the nodes based off the "prop" property and a color scale,
    edge_label="weight", # Display the "edge_prop" attribute on the edge
    edge_label_position="bottom center", # Display the edge label below the edge
    node_text=['connections']
)
# Out:
# C:\Users\decla\AppData\Local\Temp\ipykernel_2628\2433330430.py:14: DeprecationWarning:
#
# Argument `titlefont_size` is deprecated and will be removed in 0.6.0.
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'line': {'color': '#888', 'width': 1},
#               'mode': 'lines+text',
#               'text': [],
#               'type': 'scatter',
#               'uid': '576b10c4-1fca-4c97-8c58-4eeafa6b4550',
#               'x': [-0.1730652819563448, -0.12007921323647551, None,
#                     -0.1730652819563448, -0.005735905975828368, None,
#                     -0.1730652819563448, -0.04069658460269465, None,
#                     -0.1730652819563448, -0.2245588110356034, None,
#                     -0.1730652819563448, -0.4317981329178311, None,
#                     -0.1730652819563448, -0.4407554638347912, None,
#                     -0.1730652819563448, -0.2657370343440668, None,
#                     -0.12007921323647551, -0.005735905975828368, None,
#                     -0.12007921323647551, -0.04069658460269465, None,
#                     -0.12007921323647551, 0.06437953471287994, None,
#                     -0.12007921323647551, -0.23684021775480563, None,
#                     -0.12007921323647551, -0.09232862934194938, None,
#                     -0.12007921323647551, -0.2245588110356034, None,
#                     -0.12007921323647551, 0.27492105738976264, None,
#                     -0.12007921323647551, -0.4317981329178311, None,
#                     -0.12007921323647551, -0.4407554638347912, None,
#                     -0.12007921323647551, -0.2657370343440668, None,
#                     -0.005735905975828368, -0.04069658460269465, None,
#                     -0.005735905975828368, 0.06437953471287994, None,
#                     -0.005735905975828368, 0.27492105738976264, None,
#                     0.9999999999999999, 0.6922946828977474, None,
#                     0.6922946828977474, 0.27492105738976264, None,
#                     -0.4317981329178311, -0.4407554638347912, None],
#               'y': [-0.0037714787834305786, -0.0005135391299228316, None,
#                     -0.0037714787834305786, 0.012527301776722767, None,
#                     -0.0037714787834305786, -0.14958132868257507, None,
#                     -0.0037714787834305786, -0.30694683122318184, None,
#                     -0.0037714787834305786, 0.08702207575407991, None,
#                     -0.0037714787834305786, -0.0645696356866441, None,
#                     -0.0037714787834305786, 0.20352733781155044, None,
#                     -0.0005135391299228316, 0.012527301776722767, None,
#                     -0.0005135391299228316, -0.14958132868257507, None,
#                     -0.0005135391299228316, 0.1054032399689448, None,
#                     -0.0005135391299228316, -0.13499274410807555, None,
#                     -0.0005135391299228316, 0.40158994906809287, None,
#                     -0.0005135391299228316, -0.30694683122318184, None,
#                     -0.0005135391299228316, -0.023073525812125052, None,
#                     -0.0005135391299228316, 0.08702207575407991, None,
#                     -0.0005135391299228316, -0.0645696356866441, None,
#                     -0.0005135391299228316, 0.20352733781155044, None,
#                     0.012527301776722767, -0.14958132868257507, None,
#                     0.012527301776722767, 0.1054032399689448, None,
#                     0.012527301776722767, -0.023073525812125052, None,
#                     -0.07324344392053218, -0.05337737703290369, None,
#                     -0.05337737703290369, -0.023073525812125052, None,
#                     0.08702207575407991, -0.0645696356866441, None]},
#              {'hoverinfo': 'text',
#               'hovertext': [Node: Basil Hallward<br>Degree: 7<br></br>connections:
#                             51, Node: Mr. Dorian Gray<br>Degree:
#                             11<br></br>connections: 60, Node: Lord Henry
#                             Wotton<br>Degree: 5<br></br>connections: 26, Node:
#                             Adrian Singleton<br>Degree: 3<br></br>connections: 6,
#                             Node: Victor<br>Degree: 2<br></br>connections: 9, Node:
#                             Miss Sibyl Vane<br>Degree: 2<br></br>connections: 2,
#                             Node: Mr. Hubbard<br>Degree: 1<br></br>connections: 5,
#                             Node: the last Lord Kelso<br>Degree:
#                             1<br></br>connections: 1, Node: James Vane<br>Degree:
#                             1<br></br>connections: 1, Node: Henry II<br>Degree:
#                             2<br></br>connections: 2, Node: Louis XIV<br>Degree:
#                             3<br></br>connections: 4, Node: Francis
#                             Osborne<br>Degree: 3<br></br>connections: 3, Node:
#                             George Willoughby<br>Degree: 3<br></br>connections: 3,
#                             Node: Good God<br>Degree: 2<br></br>connections: 3],
#               'marker': {'color': [51, 60, 26, 6, 9, 2, 5, 1, 1, 2, 4, 3, 3, 3],
#                          'colorbar': {'thickness': 15, 'title': {'side': 'right'}, 'xanchor': 'left'},
#                          'colorscale': [[0.0, 'rgb(255,255,217)'], [0.125,
#                                         'rgb(237,248,177)'], [0.25,
#                                         'rgb(199,233,180)'], [0.375,
#                                         'rgb(127,205,187)'], [0.5,
#                                         'rgb(65,182,196)'], [0.625,
#                                         'rgb(29,145,192)'], [0.75,
#                                         'rgb(34,94,168)'], [0.875,
#                                         'rgb(37,52,148)'], [1.0, 'rgb(8,29,88)']],
#                          'line': {'width': 0},
#                          'opacity': 0.8,
#                          'reversescale': True,
#                          'showscale': True,
#                          'size': [51, 60, 26, 6, 9, 2, 5, 1, 1, 2, 4, 3, 3, 3]},
#               'mode': 'markers',
#               'text': [],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': 'ddae5405-8944-4165-a988-f6199c123b39',
#               'x': [-0.1730652819563448, -0.12007921323647551,
#                     -0.005735905975828368, -0.04069658460269465,
#                     0.06437953471287994, -0.2245588110356034, -0.23684021775480563,
#                     -0.09232862934194938, 0.9999999999999999, 0.6922946828977474,
#                     0.27492105738976264, -0.4317981329178311, -0.4407554638347912,
#                     -0.2657370343440668],
#               'y': [-0.0037714787834305786, -0.0005135391299228316,
#                     0.012527301776722767, -0.14958132868257507, 0.1054032399689448,
#                     -0.30694683122318184, -0.13499274410807555,
#                     0.40158994906809287, -0.07324344392053218,
#                     -0.05337737703290369, -0.023073525812125052,
#                     0.08702207575407991, -0.0645696356866441, 0.20352733781155044]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 0},
#               'mode': 'markers+text',
#               'text': [36, 8, 2, 1, 1, 1, 2, 8, 3, 2, 5, 1, 1, 1, 1, 1, 1, 1, 7,
#                        2, 1, 1, 1],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': '170a6ac1-b55f-487a-9e15-313013f36b2f',
#               'x': [-0.14657224759641016, -0.08940059396608659,
#                     -0.10688093327951972, -0.19881204649597412,
#                     -0.3024317074370879, -0.306910372895568, -0.2194011581502058,
#                     -0.06290755960615194, -0.08038789891958509,
#                     -0.027849839261797786, -0.17845971549564058,
#                     -0.10620392128921244, -0.17231901213603945,
#                     0.07742092207664356, -0.2759386730771533, -0.28041733853563333,
#                     -0.19290812379027117, -0.02321624528926151,
#                     0.029321814368525784, 0.13459257570696714, 0.8461473414488736,
#                     0.48360787014375506, -0.43627679837631117],
#               'y': [-0.0021425089566767053, 0.004377911496646094,
#                     -0.07667640373300282, -0.15535915500330622,
#                     0.04162529848532467, -0.03417055723503734, 0.09987792951405994,
#                     0.006006881323399968, -0.07504743390624895,
#                     0.05244485041951098, -0.06775314161899919, 0.200538204969085,
#                     -0.15373018517655235, -0.011793532471023943,
#                     0.04325426831207854, -0.032541587408283466, 0.1015068993408138,
#                     -0.06852701345292615, 0.05896527087283378,
#                     -0.005273112017701143, -0.06331041047671794,
#                     -0.03822545142251437, 0.011226220033717905]}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': '',
#                                 'x': 0.005,
#                                 'xref': 'paper',
#                                 'y': -0.002,
#                                 'yref': 'paper'}],
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'paper_bgcolor': 'rgba(0,0,0,0)',
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 16}, 'text': 'Window 5 Social Network'},
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })

# %%
# Ego Networks

character_of_interest = 'Mr. Dorian Gray'

for graph in graphs:
    remove_nodes = []
    for node in graph.nodes:
        if node == character_of_interest:
            continue

        if not (node, character_of_interest) in graph.edges:
            for _, other_node in graph.edges(node):
                graph.nodes[other_node]['connections'] -= graph.edges[node, other_node]['weight']
            remove_nodes.append(node)
    for node in remove_nodes:
        graph.remove_node(node)

# %%
window = 5

color_list = []
sizing_list = []

G = graphs[window]

for node in G.nodes():
    size_and_color = G.nodes[node]['connections']

    color_list.append(size_and_color)
    sizing_list.append(size_and_color)

ig.plot(
    G,
    title=f"Window {window} {character_of_interest} Ego Social Network",
    layout="spring",
    size_method=sizing_list, # Makes node sizes the size of the "prop" property
    color_method=color_list, # Colors the nodes based off the "prop" property and a color scale,
    edge_label="weight", # Display the "edge_prop" attribute on the edge
    edge_label_position="bottom center", # Display the edge label below the edge
    node_text=['connections']
)
# Out:
# C:\Users\decla\AppData\Local\Temp\ipykernel_2628\1327605136.py:14: DeprecationWarning:
#
# Argument `titlefont_size` is deprecated and will be removed in 0.6.0.
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'line': {'color': '#888', 'width': 1},
#               'mode': 'lines+text',
#               'text': [],
#               'type': 'scatter',
#               'uid': 'e6980468-aaba-4f4e-8393-e3f4dd21e1e6',
#               'x': [-0.08745150164968002, 0.03908411447189569, None,
#                     -0.08745150164968002, 0.18171195219338807, None,
#                     -0.08745150164968002, 0.4034296024335936, None,
#                     -0.08745150164968002, 0.4957761176699489, None,
#                     -0.08745150164968002, -0.49465592123893765, None,
#                     -0.08745150164968002, -0.7037303883968011, None,
#                     -0.08745150164968002, -0.5485118911461824, None,
#                     0.03908411447189569, 0.18171195219338807, None,
#                     0.03908411447189569, 0.4034296024335936, None,
#                     0.03908411447189569, 0.15041002060083483, None,
#                     0.03908411447189569, 0.5391219111529869, None,
#                     0.03908411447189569, -0.12216865626153213, None,
#                     0.03908411447189569, 0.4957761176699489, None,
#                     0.03908411447189569, 0.14698464017048612, None,
#                     0.03908411447189569, -0.49465592123893765, None,
#                     0.03908411447189569, -0.7037303883968011, None,
#                     0.03908411447189569, -0.5485118911461824, None,
#                     0.18171195219338807, 0.4034296024335936, None,
#                     0.18171195219338807, 0.15041002060083483, None,
#                     0.18171195219338807, 0.14698464017048612, None,
#                     -0.49465592123893765, -0.7037303883968011, None],
#               'y': [-0.05618307603094666, 0.011573874371703598, None,
#                     -0.05618307603094666, 0.06794182583009205, None,
#                     -0.05618307603094666, 0.27801253913990637, None,
#                     -0.05618307603094666, -0.6040225791525959, None,
#                     -0.05618307603094666, -0.5530482215889152, None,
#                     -0.05618307603094666, -0.236237070365843, None,
#                     -0.05618307603094666, 0.26907014390591333, None,
#                     0.011573874371703598, 0.06794182583009205, None,
#                     0.011573874371703598, 0.27801253913990637, None,
#                     0.011573874371703598, 0.4197942724534368, None,
#                     0.011573874371703598, -0.06995227584785613, None,
#                     0.011573874371703598, 1.0, None, 0.011573874371703598,
#                     -0.6040225791525959, None, 0.011573874371703598,
#                     -0.5269494327148944, None, 0.011573874371703598,
#                     -0.5530482215889152, None, 0.011573874371703598,
#                     -0.236237070365843, None, 0.011573874371703598,
#                     0.26907014390591333, None, 0.06794182583009205,
#                     0.27801253913990637, None, 0.06794182583009205,
#                     0.4197942724534368, None, 0.06794182583009205,
#                     -0.5269494327148944, None, -0.5530482215889152,
#                     -0.236237070365843, None]},
#              {'hoverinfo': 'text',
#               'hovertext': [Node: Basil Hallward<br>Degree: 7<br></br>connections:
#                             51, Node: Mr. Dorian Gray<br>Degree:
#                             11<br></br>connections: 60, Node: Lord Henry
#                             Wotton<br>Degree: 5<br></br>connections: 26, Node:
#                             Adrian Singleton<br>Degree: 3<br></br>connections: 6,
#                             Node: Victor<br>Degree: 2<br></br>connections: 9, Node:
#                             Miss Sibyl Vane<br>Degree: 2<br></br>connections: 2,
#                             Node: Mr. Hubbard<br>Degree: 1<br></br>connections: 5,
#                             Node: the last Lord Kelso<br>Degree:
#                             1<br></br>connections: 1, Node: Louis XIV<br>Degree:
#                             2<br></br>connections: 3, Node: Francis
#                             Osborne<br>Degree: 3<br></br>connections: 3, Node:
#                             George Willoughby<br>Degree: 3<br></br>connections: 3,
#                             Node: Good God<br>Degree: 2<br></br>connections: 3],
#               'marker': {'color': [51, 60, 26, 6, 9, 2, 5, 1, 3, 3, 3, 3],
#                          'colorbar': {'thickness': 15, 'title': {'side': 'right'}, 'xanchor': 'left'},
#                          'colorscale': [[0.0, 'rgb(255,255,217)'], [0.125,
#                                         'rgb(237,248,177)'], [0.25,
#                                         'rgb(199,233,180)'], [0.375,
#                                         'rgb(127,205,187)'], [0.5,
#                                         'rgb(65,182,196)'], [0.625,
#                                         'rgb(29,145,192)'], [0.75,
#                                         'rgb(34,94,168)'], [0.875,
#                                         'rgb(37,52,148)'], [1.0, 'rgb(8,29,88)']],
#                          'line': {'width': 0},
#                          'opacity': 0.8,
#                          'reversescale': True,
#                          'showscale': True,
#                          'size': [51, 60, 26, 6, 9, 2, 5, 1, 3, 3, 3, 3]},
#               'mode': 'markers',
#               'text': [],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': 'e1dd0a39-4527-4b66-af39-cef908a12b54',
#               'x': [-0.08745150164968002, 0.03908411447189569,
#                     0.18171195219338807, 0.4034296024335936, 0.15041002060083483,
#                     0.4957761176699489, 0.5391219111529869, -0.12216865626153213,
#                     0.14698464017048612, -0.49465592123893765, -0.7037303883968011,
#                     -0.5485118911461824],
#               'y': [-0.05618307603094666, 0.011573874371703598,
#                     0.06794182583009205, 0.27801253913990637, 0.4197942724534368,
#                     -0.6040225791525959, -0.06995227584785613, 1.0,
#                     -0.5269494327148944, -0.5530482215889152, -0.236237070365843,
#                     0.26907014390591333]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 0},
#               'mode': 'markers+text',
#               'text': [36, 8, 2, 1, 1, 1, 2, 8, 3, 2, 5, 1, 1, 1, 1, 1, 1, 1, 7,
#                        2, 1],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': '0f594c6f-b494-489a-8b42-28b118ea25f5',
#               'x': [-0.024183693588892163, 0.04713022527185402,
#                     0.1579890503919568, 0.20416230801013444, -0.2910537114443088,
#                     -0.39559094502324055, -0.31798169639793117,
#                     0.11039803333264188, 0.22125685845274465, 0.09474706753636526,
#                     0.28910301281244133, -0.04154227089481822, 0.26743011607092226,
#                     0.09303437732119091, -0.22778590338352098,
#                     -0.33232313696245275, -0.25471388833714337,
#                     0.29257077731349085, 0.16606098639711145, 0.16434829618193708,
#                     -0.5991931548178694],
#               'y': [-0.022304600829621532, 0.005879374899572694,
#                     0.11091473155447985, -0.3301028275917713, -0.3046156488099309,
#                     -0.14621007319839482, 0.10644353393748333, 0.03975785010089782,
#                     0.14479320675580498, 0.2156840734125702, -0.029189200738076265,
#                     0.5057869371858518, -0.29622435239044614, -0.25768777917159535,
#                     -0.2707371736086058, -0.1123315979970697, 0.14032200913880846,
#                     0.17297718248499921, 0.24386804914176444, -0.22950380344240115,
#                     -0.3946426459773791]}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': '',
#                                 'x': 0.005,
#                                 'xref': 'paper',
#                                 'y': -0.002,
#                                 'yref': 'paper'}],
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'paper_bgcolor': 'rgba(0,0,0,0)',
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 16}, 'text': 'Window 5 Mr. Dorian Gray Ego Social Network'},
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })
