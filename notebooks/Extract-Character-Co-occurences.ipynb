# %%
import pandas as pd
import networkx as nx
import igviz as ig

# %%
characters_df = pd.read_csv('../data/DorianGray/processed_characters.csv')
characters_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat               text  \
# 0              4    112           77         79  PROP  PER  Lord Henry Wotton
# 1              6    112          156        156  PRON  PER                him
# 2             14    113          289        290  PROP  PER     Basil Hallward
# 3             27    113          396        396  PROP  PER              Basil
# 4             29    112          408        409  PROP  PER         Lord Henry
# ...          ...    ...          ...        ...   ...  ...                ...
# 7148       14196    307        95668      95668  PRON  PER                 he
# 7149       14197    307        95674      95674  PRON  PER                 He
# 7150       14215    115        95814      95816  PROP  PER    Mr. Dorian Gray
# 7151       14232    268        95885      95885  PROP  PER            Francis
# 7152       14233    268        95900      95900  PRON  PER                 he
#
#          character_name
# 0     Lord Henry Wotton
# 1     Lord Henry Wotton
# 2        Basil Hallward
# 3        Basil Hallward
# 4     Lord Henry Wotton
# ...                 ...
# 7148      Alan Campbell
# 7149      Alan Campbell
# 7150    Mr. Dorian Gray
# 7151    Francis Osborne
# 7152    Francis Osborne
#
# [7153 rows x 8 columns]

# %%
tokens_df = pd.read_csv('../data/DorianGray/character-tagging/DorianGray.tokens', delimiter='\t')
tokens_df
# Out:
#        paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0                 0            0                         0
# 1                 0            0                         1
# 2                 0            0                         2
# 3                 0            0                         3
# 4                 0            0                         4
# ...             ...          ...                       ...
# 96039          1490         6159                        11
# 96040          1490         6159                        12
# 96041          1490         6159                        13
# 96042          1490         6159                        14
# 96043          1490         6159                        15
#
#        token_ID_within_document        word      lemma  byte_onset  \
# 0                             0         The        the           0
# 1                             1      studio     studio           4
# 2                             2         was         be          11
# 3                             3      filled       fill          15
# 4                             4        with       with          22
# ...                         ...         ...        ...         ...
# 96039                     96039  recognized  recognize      426538
# 96040                     96040         who        who      426549
# 96041                     96041          it         it      426553
# 96042                     96042         was         be      426556
# 96043                     96043           .          .      426559
#
#       byte_offset POS_tag fine_POS_tag dependency_relation syntactic_head_ID  \
# 0               3     DET           DT                 det                 1
# 1              10    NOUN           NN           nsubjpass                 3
# 2              14     AUX          VBD             auxpass                 3
# 3              21    VERB          VBN                ROOT                 3
# 4              26     ADP           IN                prep                 3
# ...           ...     ...          ...                 ...               ...
# 96039      426548    VERB          VBD               relcl             96036
# 96040      426552    PRON           WP                attr             96042
# 96041      426555    PRON          PRP               nsubj             96042
# 96042      426559     AUX          VBD               ccomp             96039
# 96043      426560   PUNCT            .               punct             96029
#
#       event
# 0         O
# 1         O
# 2         O
# 3         O
# 4         O
# ...     ...
# 96039     O
# 96040     O
# 96041     O
# 96042     O
# 96043     O
#
# [96044 rows x 13 columns]

# %%
# Paragraph based network

characters_paragraph_mention_df = characters_df.copy()
characters_paragraph_mention_df['paragraph'] = characters_paragraph_mention_df.start_token.map(
    lambda x: tokens_df.iloc[x].paragraph_ID
)
characters_paragraph_mention_df
# Out:
#       Unnamed: 0  COREF  start_token  end_token  prop  cat               text  \
# 0              4    112           77         79  PROP  PER  Lord Henry Wotton
# 1              6    112          156        156  PRON  PER                him
# 2             14    113          289        290  PROP  PER     Basil Hallward
# 3             27    113          396        396  PROP  PER              Basil
# 4             29    112          408        409  PROP  PER         Lord Henry
# ...          ...    ...          ...        ...   ...  ...                ...
# 7148       14196    307        95668      95668  PRON  PER                 he
# 7149       14197    307        95674      95674  PRON  PER                 He
# 7150       14215    115        95814      95816  PROP  PER    Mr. Dorian Gray
# 7151       14232    268        95885      95885  PROP  PER            Francis
# 7152       14233    268        95900      95900  PRON  PER                 he
#
#          character_name  paragraph
# 0     Lord Henry Wotton          1
# 1     Lord Henry Wotton          1
# 2        Basil Hallward          2
# 3        Basil Hallward          4
# 4     Lord Henry Wotton          4
# ...                 ...        ...
# 7148      Alan Campbell       1483
# 7149      Alan Campbell       1483
# 7150    Mr. Dorian Gray       1486
# 7151    Francis Osborne       1488
# 7152    Francis Osborne       1489
#
# [7153 rows x 9 columns]

# %%
paragraph_windows = 10
paragraphs_per_window = characters_paragraph_mention_df.paragraph.max() // paragraph_windows

sizes = paragraph_windows * [paragraphs_per_window]
for i in range(characters_paragraph_mention_df.paragraph.max() - sum(sizes)):
    sizes[i] += 1

# %%
graphs = []

G = nx.Graph()

curr_graph = 0

for paragraph, sub_df in characters_paragraph_mention_df.groupby(characters_paragraph_mention_df.paragraph):
    
    if paragraph > sizes[curr_graph] + sum(sizes[:curr_graph]):
        graphs.append(G)
        curr_graph += 1
        G = nx.Graph()
    
    if sub_df.character_name.unique().size == 1:
        continue
    
    pairs = []
    for i, name in enumerate(sub_df.character_name.unique()):
        
        if name not in G.nodes:
            G.add_node(name, connections=sub_df.character_name.unique().size - 1)
        else:
            G.nodes[name]['connections'] += sub_df.character_name.unique().size - 1

        for o_name in sub_df.character_name.unique()[i + 1:]:
            
            if o_name not in G.nodes:
                G.add_node(o_name, connections=0)
            if (name, o_name) not in G.edges:
                G.add_edge(name, o_name, weight=1)
            else:
                G.edges[name, o_name]['weight'] += 1

# %%
window = 4

color_list = []
sizing_list = []

G = graphs[window]

for node in G.nodes():
    size_and_color = G.nodes[node]['connections']

    color_list.append(size_and_color)
    sizing_list.append(size_and_color)

ig.plot(
    G,
    title=f"Window {window} Social Network",
    layout="spring",
    size_method=sizing_list, # Makes node sizes the size of the "prop" property
    color_method=color_list, # Colors the nodes based off the "prop" property and a color scale,
    edge_label="weight", # Display the "edge_prop" attribute on the edge
    edge_label_position="bottom center", # Display the edge label below the edge
    node_text=['connections']
)
# Out:
# C:\Users\decla\AppData\Local\Temp\ipykernel_30448\3849022792.py:14: DeprecationWarning:
#
# Argument `titlefont_size` is deprecated and will be removed in 0.6.0.
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'line': {'color': '#888', 'width': 1},
#               'mode': 'lines+text',
#               'text': [],
#               'type': 'scatter',
#               'uid': 'bd02d3e9-d8e1-487c-ba13-596378793dc0',
#               'x': [0.004206855807078213, 0.2226619468873262, None,
#                     0.004206855807078213, 0.027779128928134958, None,
#                     0.004206855807078213, 0.10676095538771309, None,
#                     0.004206855807078213, -0.22675343634127856, None,
#                     0.004206855807078213, -0.01583291865957878, None,
#                     0.2226619468873262, 0.027779128928134958, None,
#                     0.2226619468873262, -0.22675343634127856, None,
#                     0.2226619468873262, 0.10676095538771309, None,
#                     0.2226619468873262, -1.0, None, 0.2226619468873262,
#                     0.8811774679906058, None, 0.027779128928134958,
#                     -0.22675343634127856, None, 0.027779128928134958,
#                     0.10676095538771309, None, 0.027779128928134958,
#                     0.8811774679906058, None, 0.027779128928134958,
#                     -0.01583291865957878, None, 0.027779128928134958, -1.0, None,
#                     -0.22675343634127856, 0.10676095538771309, None,
#                     -0.22675343634127856, -1.0, None, -0.22675343634127856,
#                     0.8811774679906058, None],
#               'y': [-0.221137192815382, -0.13373951895843264, None,
#                     -0.221137192815382, 0.059301146815793494, None,
#                     -0.221137192815382, -0.7243139028990803, None,
#                     -0.221137192815382, -0.10744884746625913, None,
#                     -0.221137192815382, 0.808118653035761, None,
#                     -0.13373951895843264, 0.059301146815793494, None,
#                     -0.13373951895843264, -0.10744884746625913, None,
#                     -0.13373951895843264, -0.7243139028990803, None,
#                     -0.13373951895843264, 0.07802318507530373, None,
#                     -0.13373951895843264, 0.2411964772122956, None,
#                     0.059301146815793494, -0.10744884746625913, None,
#                     0.059301146815793494, -0.7243139028990803, None,
#                     0.059301146815793494, 0.2411964772122956, None,
#                     0.059301146815793494, 0.808118653035761, None,
#                     0.059301146815793494, 0.07802318507530373, None,
#                     -0.10744884746625913, -0.7243139028990803, None,
#                     -0.10744884746625913, 0.07802318507530373, None,
#                     -0.10744884746625913, 0.2411964772122956, None]},
#              {'hoverinfo': 'text',
#               'hovertext': [Node: Lord Henry Wotton<br>Degree:
#                             5<br></br>connections: 68, Node: Miss Sibyl
#                             Vane<br>Degree: 6<br></br>connections: 51, Node: Mr.
#                             Dorian Gray<br>Degree: 7<br></br>connections: 89, Node:
#                             Basil Hallward<br>Degree: 6<br></br>connections: 41,
#                             Node: Juliet<br>Degree: 4<br></br>connections: 11,
#                             Node: Prince Charming<br>Degree: 3<br></br>connections:
#                             4, Node: Victor<br>Degree: 2<br></br>connections: 5,
#                             Node: Good God<br>Degree: 3<br></br>connections: 3],
#               'marker': {'color': [68, 51, 89, 41, 11, 4, 5, 3],
#                          'colorbar': {'thickness': 15, 'title': {'side': 'right'}, 'xanchor': 'left'},
#                          'colorscale': [[0.0, 'rgb(255,255,217)'], [0.125,
#                                         'rgb(237,248,177)'], [0.25,
#                                         'rgb(199,233,180)'], [0.375,
#                                         'rgb(127,205,187)'], [0.5,
#                                         'rgb(65,182,196)'], [0.625,
#                                         'rgb(29,145,192)'], [0.75,
#                                         'rgb(34,94,168)'], [0.875,
#                                         'rgb(37,52,148)'], [1.0, 'rgb(8,29,88)']],
#                          'line': {'width': 0},
#                          'opacity': 0.8,
#                          'reversescale': True,
#                          'showscale': True,
#                          'size': [68, 51, 89, 41, 11, 4, 5, 3]},
#               'mode': 'markers',
#               'text': [],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': 'e0dbe57d-93d2-49e7-8a39-82317936fcf6',
#               'x': [0.004206855807078213, 0.2226619468873262,
#                     0.027779128928134958, -0.22675343634127856,
#                     0.10676095538771309, 0.8811774679906058, -0.01583291865957878,
#                     -1.0],
#               'y': [-0.221137192815382, -0.13373951895843264,
#                     0.059301146815793494, -0.10744884746625913,
#                     -0.7243139028990803, 0.2411964772122956, 0.808118653035761,
#                     0.07802318507530373]},
#              {'hoverinfo': 'text',
#               'marker': {'opacity': 0},
#               'mode': 'markers+text',
#               'text': [15, 41, 3, 8, 1, 20, 11, 3, 1, 1, 18, 3, 2, 4, 1, 2, 1, 1],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': '3ec6e0fe-1dd7-4939-bf8e-01705ec2bddf',
#               'x': [0.11343440134720222, 0.015992992367606585,
#                     0.055483905597395654, -0.11127329026710017,
#                     -0.005813031426250283, 0.12522053790773058,
#                     -0.002045744726976176, 0.16471145113751964,
#                     -0.3886690265563369, 0.551919707438966, -0.0994871537065718,
#                     0.06727004215792402, 0.4544782984593704, 0.00597310513427809,
#                     -0.48611043553593253, -0.05999624047678274,
#                     -0.6133767181706393, 0.32721201582466364],
#               'y': [-0.17743835588690732, -0.08091802299979425,
#                     -0.47272554785723114, -0.16429302014082056, 0.2934907301101895,
#                     -0.03721918607131958, -0.12059418321234588,
#                     -0.42902671092875644, -0.027858166941564455,
#                     0.053728479126931475, -0.024073850325232817,
#                     -0.3325063780416434, 0.15024881201404455, 0.43370989992577724,
#                     0.06866216594554861, -0.4158813751826697,
#                     -0.014712831195477699, 0.06687381487301823]}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': '',
#                                 'x': 0.005,
#                                 'xref': 'paper',
#                                 'y': -0.002,
#                                 'yref': 'paper'}],
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'paper_bgcolor': 'rgba(0,0,0,0)',
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 16}, 'text': 'Window 4 Social Network'},
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })
